# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\anaconda3\lib\site-packages (from opencv-python) (1.20.3)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.5.64

# %%
from cv2 import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# # Plotting

# %%
img1 = cv2.imread("Resources/img6.png", 0)

# %%
plt.imshow(img1)

# %% [markdown]
# # Arithmetic Operations

# %%
img2 = cv2.imread("Resources/img2.png", 0)

# %% [markdown]
# # Addition

# %%
result = img1 + img2

# %%
plt.imshow(result)

# %% [markdown]
# # Subtraction

# %%
res = img1 - img2

# %%
plt.imshow(res)

# %% [markdown]
# # Multiplication

# %%
result = img1 * img2
plt.imshow(result)

# %% [markdown]
# # Division

# %%
result = img1 / img2
plt.imshow(result)
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_6140/1585750730.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   result = img1 / img2
# C:\Users\user\AppData\Local\Temp/ipykernel_6140/1585750730.py:1: RuntimeWarning: invalid value encountered in true_divide
#   result = img1 / img2

# %% [markdown]
# # Blurring of Image

# %%
img1 = cv2.imread("Resources/img2.png")
img = cv2.cvtColor(img1, cv2.COLOR_BGR2HSV)
figure_size = 7
result = cv2.blur(img, (figure_size, figure_size))
plt.figure(figsize = (11, 6))
plt.subplot(121), plt.imshow(cv2.cvtColor(img, cv2.COLOR_HSV2RGB)), plt.title("Original")
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(cv2.cvtColor(result, cv2.COLOR_HSV2RGB)), plt.title("Blurred")
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Zooming an Image

# %%
img1 = cv2.imread("Resources/img2.png")

# %%
(height, width) = img1.shape[0:2]
zoom = cv2.resize(img1, None, fx = 1.5, fy = 1.5, interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom = cv2.resize(img1, (int(width*2), int(height*2)) , interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# # Rotate an Image

# %%
m = cv2.getRotationMatrix2D((width/2, height/2), 30, 1)
rotate = cv2.warpAffine(img1, m, (height, width))
plt.imshow(rotate)

# %% [markdown]
# # Translate an Image

# %%
import numpy as np

# %%
m = np.float32([[1, 0, 50], [0, 1, 100]])
dst = cv2.warpAffine(img, m, (height, width))
plt.imshow(dst)
